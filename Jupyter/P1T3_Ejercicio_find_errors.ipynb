# %% [markdown]
# #Buscando errores en el código fuente:

# %% [markdown]
# ##P1T3_A

# %% [markdown]
# 1.   Pedia un número y se le estaba dando un string.
# 2.   Se estaba llamando mal la función.
# 3.   Como el iva lo estabamos definiendo dentro de los valores que reciben la función no se debe llamar afuera

# %%
bruto = int(input('Cual es el valor bruto del producto: '))
def f_aplica_iva(bruto, iva = 0.19):
    total_iva = bruto*iva   
    return total_iva
f_aplica_iva(bruto)
# Out:
# Cual es el valor bruto del producto: 10000
# 1900.0

# %% [markdown]
# #P1T3_B

# %% [markdown]
# 1.   Eran tuplas y las tuplas son valores que no se pueden cambiar
# 2.

# %%
u = [1, 2, 3]
v = [4, 5, 6]

def multiplicar_vector(u, v):
    for i in range(len(u)):
      for j in range(len(v)):
          u[i] *= v[j]
          print( u[i] ,"*",v[j])
    return sum(u)

multiplicar_vector(u, v)
# Out:
# 4 * 4
# 20 * 5
# 120 * 6
# 8 * 4
# 40 * 5
# 240 * 6
# 12 * 4
# 60 * 5
# 360 * 6
# 720

# %% [markdown]
# #P1T3_C

# %% [markdown]
# 1.   La variable total no estaba definida
# 2.   En el range se le estaba pasando un string y debe recibir numeros.

# %%
total =0 
for i in range(int(input("Total de números? "))):
  total += int(input("Ingrese un valor: "))
print(f"El total de la suma es: {total} ")
# Out:
# Total de números? 2
# Ingrese un valor: 2
# Ingrese un valor: 2
# El total de la suma es: 4
