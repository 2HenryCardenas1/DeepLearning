# %% [markdown]
# #Instalar Librerias

# %% [markdown]
# pip install nombre libreria

# %%
pip install pandas

# %% [markdown]
# #Habilitar google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Ejercicio 1 PANDA

# %%
import pandas as pd
#Lectura de datos de un archivo csv
dataframe = pd.read_csv("https://raw.githubusercontent.com/luisFernandoCastellanosG/Machine_learning/master/DataScience/DataSet's/prestamos_records.csv")
dataframe.head(10)
#print(dataframe.shape) #mostrar la cantidad de datos y columnas del dataframe
# Out:
# (8000, 7)

# %%
dataframe.head(10)

# %%
#Insertar nueva columna al final
dataframe['Total']=10

#Insertar una nueva columna al inicio
dataframe.insert(0,'Columna Nueva',dataframe.mean(1))
