# %% [markdown]
# # Ejercicios OpenSource con sklearn.datasets
#
# ---

# %% [markdown]
# ##Regresión lineal al dataset  load_boston

# %% [markdown]
# ###Librerías necesarias

# %%
import numpy as np              #Mejora el soporte para vectores y matrices
import pandas as pd             #Estructura de datos (Ciencia de datos)

import matplotlib.pyplot as plt #Para graficar
import seaborn as sns           #interfaz de alto nivel para dibujar gráficos estadísticos (basada en matplotlib)

# %% [markdown]
# ### cargamos los datos de la biblioteca scikit-learn

# %%
from sklearn.datasets import load_boston
boston_dataset = load_boston()

# %% [markdown]
# ###Conociendo los datos que tiene el dataset

# %%
print(boston_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# *   datos/data: contiene la información de varias casas
# *   feature_names: nombres de las características
# *   DESCR: describe el conjunto de datos
# *   **objetivo/traget: los precios de la casa (caracterista más relevante)**
# ---
#
#
# Conociendo las caracteristicas que tienen los datos:

# %%
boston_dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %% [markdown]
# *   CRIM: Tasa de delincuencia per cápita por ciudad
# *   ZN: Proporción de terrenos residenciales divididos en zonas para lotes de más de 25,000 pies cuadrados
# *   INDUS: Proporción de acres comerciales no minoristas por ciudad
# *   CHAS: Variable ficticia de Charles River (= 1 si el tramo limita con el río; 0 en caso contrario)
# *   NOX: concentración de óxido nítrico (partes por 10 millones)
# *   RM: Número medio de habitaciones por vivienda
# *   EDAD: Proporción de unidades ocupadas por el propietario construidas antes de 1940
# *   DIS: distancias ponderadas a cinco centros de empleo de Boston
# *   RAD: Índice de accesibilidad a carreteras radiales
# *   TAX/IMPUESTO: Tasa de impuesto a la propiedad de valor total por USD 10.000
# *   PTRATIO: Proporción alumno/profesor por municipio
# *   B: 1000 (Bk - 0,63)², donde Bk es la proporción de personas de ascendencia afroamericana por ciudad
# *   LSTAT: porcentaje de la población de menor estatus
# *   MEDV: Valor medio de las viviendas ocupadas por sus propietarios en $ 1000 (REVISAR)

# %% [markdown]
# ### Creamos una tabla de datos usando **pandas**
# (facilita el manejo de los datos)

# %%
#creamos una tabla (tipo excel con PANDAS, con titulos para faciliar la manipulación)
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston.head(10)   #imprimimos las primeras 10 filas
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
# 5  0.02985   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.12   5.21
# 6  0.08829  12.5   7.87   0.0  0.524  ...  5.0  311.0     15.2  395.60  12.43
# 7  0.14455  12.5   7.87   0.0  0.524  ...  5.0  311.0     15.2  396.90  19.15
# 8  0.21124  12.5   7.87   0.0  0.524  ...  5.0  311.0     15.2  386.63  29.93
# 9  0.17004  12.5   7.87   0.0  0.524  ...  5.0  311.0     15.2  386.71  17.10
#
# [10 rows x 13 columns]

# %% [markdown]
# Podemos ver que el valor de destino falta en los datos.
# Creamos una nueva columna de valores de destino y la agregamos a la tabla la llamamos **MEDV**

# %%
#Agregamos en la tabla los valores de target del dataset
boston['MEDV'] = boston_dataset.target
boston.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
# 5  0.02985   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.12   5.21  28.7
# 6  0.08829  12.5   7.87   0.0  0.524  ...  311.0     15.2  395.60  12.43  22.9
# 7  0.14455  12.5   7.87   0.0  0.524  ...  311.0     15.2  396.90  19.15  27.1
# 8  0.21124  12.5   7.87   0.0  0.524  ...  311.0     15.2  386.63  29.93  16.5
# 9  0.17004  12.5   7.87   0.0  0.524  ...  311.0     15.2  386.71  17.10  18.9
#
# [10 rows x 14 columns]

# %% [markdown]
# ###Conociendo los datos

# %%
#Cuantos registros tiene el dataset (rows)
#boston.shape[1]
#boston.index
#Cuántos datos tiene cada registro (columns)
#boston.shape[1]
#Hay datos nulos (null) en el dataset?
boston.isnull().sum()
#boston.isnull().values.any()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ###Graficando los valores
# reviseos la estimación de la densidad del kernel de los valores de las casas

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})  #tamaño del grafico
sns.distplot(boston['MEDV'])                #agregamos los datos
plt.show()                                  #visualizamos el grafico
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###matriz de correlación
# para medir las relaciones lineales entre las variables y de esa forma determinar que valores son más practicos para entregar un modelo de regresión lineal.

# %%
#función de correlación de pandas (cercano a 1 es la mejor correlación, negativos la peor)
correlation_matrix = boston.corr().round(2)
# annot = True (para imprimir los valores dentro del cuadrado)
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# Se deben seleccionar aquellas características que tienen una alta correlación (ya se positiva o negativa) con nuestra variable de destino (MEDV).
#
# Entre 0.7 a 0.74 sea positivo o negativo:
# MEDV 	<->	RM
# MEDV	<->	LSTAT
# Se deben descartar las características que tengan multi-colinealidad (correlación utópica que solo se podría dar en laboratorio), son aquellas que tengan valores superiores 0,74:
# RAD<->TAX
# DIS<->AGE
#
# Usaremos un gráfico de dispersión para ver cómo estas características varían
#
# RM vs MEDV
# LSTAT vs MEDV

# %% [markdown]
# ### Graficando variables descartadas

# %% [markdown]
# si no creemos en tablas, pues generemos graficas de comparación entre variables y a ojo descartamos

# %%
boston[1:1]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
sns.set(style='whitegrid', context='notebook')
features_plot = boston_dataset.feature_names
#features_plot = boston[1:1]
sns.pairplot(boston[features_plot], height=2.0);
plt.tight_layout()
plt.show()

# %% [markdown]
# #### descartando RAD vs TAX

# %%
X = boston['RAD']
y = boston['TAX']
plt.scatter(X, y)
plt.xlabel('RAD-Número de habitaciones')
plt.ylabel('TAX-valor predial de la propiedad')
plt.show()

# %% [markdown]
# ####descartando DIS vs AGE

# %%
X = boston['DIS']
y = boston['AGE']
plt.scatter(X, y)
plt.xlabel('DIS-distancia a oficinas')
plt.ylabel('AGE-viviendas construidas <1940')
plt.show()

# %% [markdown]
# ###Graficando variables seleccionadas

# %% [markdown]
# #### MEDV vs RM

# %%
X = boston['MEDV']
y = boston['RM']
plt.scatter(X,y, s=15, alpha=0.5)
plt.xlabel('MEDV-valor medio de vivienda')
plt.ylabel('RM- # de habitacions x vivienda')
plt.show()

# %% [markdown]
# ####LSTAT vs MEDV

# %%
X = boston['MEDV']
y = boston['LSTAT']
plt.scatter(X,y, s=15, alpha=0.5)
plt.xlabel('MEDV-valor medio de vivienda')
plt.ylabel('LSTAT- % de pobres')
plt.show()

# %%
plt.figure(figsize=(20, 5))

features = ['LSTAT', 'RM']
target = boston['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = boston[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %% [markdown]
# ### 8. Preparación de los datos para el entrenamiento del modelo

# %% [markdown]
# Regresión lineal:
#
#
# > Y = mX + b
#
#
# Donde Y es el resultado, X es la variable, m la pendiente (o coeficiente) de la recta y b la constante o también conocida como el “punto de corte con el eje Y” en la gráfica (cuando X=0)
# > Concatenamos las columnas que seleccionamos para entrenar:
# X = LSTAT y RM
# Y = MEDV

# %%
#Entrenando con una sola variable en X

#X = pd.DataFrame(np.c_[boston['LSTAT']], columns = ['LSTAT'])
#X = pd.DataFrame(np.c_[boston['RM']], columns = ['RM'])

#entrenando con dos variables en X
#DIS-NOX
#X = pd.DataFrame(np.c_[boston['DIS'], boston['NOX']], columns = ['DIS','NOX'])
#Y = boston['MEDV']
#CRIM - LSTAT 
#X = pd.DataFrame(np.c_[boston['CRIM'], boston['LSTAT']], columns = ['CRIM','LSTAT'])
#Y = boston['MEDV']
#ZN - INDUS
#X = pd.DataFrame(np.c_[boston['ZN'], boston['INDUS']], columns = ['ZN','INDUS'])
#Y = boston['MEDV']
#AGE -DIS
X = pd.DataFrame(np.c_[boston['AGE'], boston['DIS']], columns = ['AGE','DIS'])
Y = boston['MEDV']

# %% [markdown]
# ### 9. Dividir los datos en conjuntos de entrenamiento (80%) y pruebas (20%)

# %%
from sklearn.model_selection import train_test_split
#DIS - NOX 
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=20)
print("x80%: "+str(X_train.shape) +", x20%: "+str(X_test.shape))
print("y80%: "+str(Y_train.shape) +", y20%: "+str(Y_test.shape))"""

#CRIM - LSTAT 0.46
#Precisión del modelo: 0.7383159417142253 con random_state=20 
#Precision del modelo: 0.7418633188382385 con random state=5
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print("x80%: "+str(X_train.shape) +", x20%: "+str(X_test.shape))
print("y80%: "+str(Y_train.shape) +", y20%: "+str(Y_test.shape)) """

#ZN - INDUS -0.53
#Precisión del modelo: 0.5949052657768112 con random_state = 5
#Precisión del modelo: 0.7470636408823214 con random_state = 10
#Precisión del modelo: 0.6968363098150216 con random_state = 20
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=20)
print("x80%: "+str(X_train.shape) +", x20%: "+str(X_test.shape))
print("y80%: "+str(Y_train.shape) +", y20%: "+str(Y_test.shape))  """

#AGE -DIS -0.77
#Precisión del modelo: 0.7578489571591229  con random_state = 5
#Precisión del modelo: 0.7631798494620157  con random_state = 30
#Precisión del modelo: 0.7997512634844363  con random_state = 2
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)
print("x80%: "+str(X_train.shape) +", x20%: "+str(X_test.shape))
print("y80%: "+str(Y_train.shape) +", y20%: "+str(Y_test.shape))  """
# Out:
# x80%: (404, 2), x20%: (102, 2)
# y80%: (404,), y20%: (102,)

# %% [markdown]
# ###9. Dividir los datos en conjuntos de entrenamiento (70%) y pruebas (30%)

# %%
from sklearn.model_selection import train_test_split

#DIS - NOX 
#Precisión del modelo: 0.8137154330034226 con random_state = 20
#Precisión del modelo: 0.7196986928952909 con random_state = 5
# Precisión del modelo: 0.6683935162235879 con random_state = 15
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=15)
print("x70%: "+str(X_train.shape) +", x30%: "+str(X_test.shape))
print("y70%: "+str(Y_train.shape) +", y30%: "+str(Y_test.shape))"""

#CRIM - LSTAT 0.46
#Precisión del modelo: 0.6554532716866162 con random_state=5 
#Precisión del modelo: 0.7313868329462719 con random state=10
#Precisión del modelo: 0.6659159843031395 con random state=30
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=30)
print("x70%: "+str(X_train.shape) +", x30%: "+str(X_test.shape))
print("y70%: "+str(Y_train.shape) +", y30%: "+str(Y_test.shape)) """

#ZN - INDUS -0.53
#Precisión del modelo: 0.7038053468036202 con random_state = 5
#Precisión del modelo: 0.680941569251398 con random_state = 10
#Precisión del modelo: 0.8066121871374812 con random_state = 20
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size =0.3, random_state=20)
print("x70%: "+str(X_train.shape) +", x30%: "+str(X_test.shape))
print("y70%: "+str(Y_train.shape) +", y30%: "+str(Y_test.shape))  """


#AGE -DIS -0.77
#Precisión del modelo: 0.708385356097659  con random_state = 5
#Precisión del modelo: 0.6840383837528352  con random_state = 30
#Precisión del modelo: 0.7888383553306595  con random_state = 2
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=5)
print("x70%: "+str(X_train.shape) +", x30%: "+str(X_test.shape))
print("y70%: "+str(Y_train.shape) +", y30%: "+str(Y_test.shape))
# Out:
# x70%: (354, 2), x30%: (152, 2)
# y70%: (354,), y30%: (152,)

# %% [markdown]
# ###9.Dividir los datos en conjuntos de entrenamiento (60%) y pruebas (40%)

# %%
from sklearn.model_selection import train_test_split

#DIS - NOX 
#Precisión del modelo: 0.7990644041660613 con random_state = 20
#Precisión del modelo: 0.6677622182040526 con random_state = 5
#Precisión del modelo: 0.7865414911170192 con random_state = 15
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.4, random_state=5)
print("x60%: "+str(X_train.shape) +", x40%: "+str(X_test.shape))
print("y60%: "+str(Y_train.shape) +", y40%: "+str(Y_test.shape))
"""
#CRIM - LSTAT 0.46
#Precisión del modelo: 0.7841335115211627 con random_state=5 
#Precisión del modelo: 0.7124386572133785 con random state=10
#Precisión del modelo: 0.6506019783295993 con random state=30
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.4, random_state=5)
print("x60%: "+str(X_train.shape) +", x40%: "+str(X_test.shape))
print("y60%: "+str(Y_train.shape) +", y40%: "+str(Y_test.shape))
"""

#ZN - INDUS -0.53
#Precisión del modelo: 0.6633375422201837 con random_state = 5
#Precisión del modelo: 0.5456535968454396 con random_state = 10
#Precisión del modelo: 0.7814978473089449 con random_state = 20
"""X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size =0.4, random_state=5)
print("x60%: "+str(X_train.shape) +", x40%: "+str(X_test.shape))
print("y60%: "+str(Y_train.shape) +", y40%: "+str(Y_test.shape))
"""


#AGE -DIS -0.77
#Precisión del modelo: 0.7259542157174892  con random_state = 5
#Precisión del modelo: 0.7783018217772673  con random_state = 30
#Precisión del modelo: 0.792708114809324  con random_state = 2
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.4, random_state=2)
print("x60%: "+str(X_train.shape) +", x40%: "+str(X_test.shape))
print("y60%: "+str(Y_train.shape) +", y40%: "+str(Y_test.shape))
# Out:
# x60%: (303, 2), x40%: (203, 2)
# y60%: (303,), y40%: (203,)

# %% [markdown]
# ###10.entrenando un modelo de regresión lineal

# %%
from sklearn.linear_model import LinearRegression

lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### 11.Evaluación del modelo
# Evaluamos el modelo utilizando RMSE y R2-score.

# %%
# poner a prueba la maquina (modelo)
Y_pred = lin_model.predict(X_test)
#plt.scatter(X_test['DIS'], Y_test)
#plt.scatter(X_test['CRIM'], Y_test)
#plt.scatter(X_test['ZN'], Y_test)
plt.scatter(X_test['AGE'], Y_test)
plt.plot(X_test, Y_pred, color='red', linewidth=3)
plt.title('Regresión Lineal Simple')
#plt.xlabel('Número de habitaciones')
plt.xlabel('% de población pobre')
plt.ylabel('Valor medio de la vivienda')
plt.show()
print('\n PRESICIÓN DEL MODELO REGRESIÓN LINEAL SIMPLE')
print(lin_model.score(X_train, Y_train))
# Out:
#  PRESICIÓN DEL MODELO REGRESIÓN LINEAL SIMPLE
# 0.16647651267031371

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
# evaluación del modelo para el conjunto de entrenamiento
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("El modelo de rendimiento para el conjunto de entrenamiento.")
print("--------------------------------------")
print('RMSE es {}'.format(rmse))
print('R2 resultado es {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("El rendimiento del modelo para el conjunto de pruebas")
print("--------------------------------------")
print('RMSE es {}'.format(rmse))
print('R2 resultado es {}'.format(r2))
# Out:
# El modelo de rendimiento para el conjunto de entrenamiento.
# --------------------------------------
# RMSE es 7.831346766081
# R2 resultado es 0.16647651267031371
#
#
# El rendimiento del modelo para el conjunto de pruebas
# --------------------------------------
# RMSE es 9.436116052205394
# R2 resultado es 0.10561035143659558

# %% [markdown]
# ##Separar los datos (TRAIN, TEST)

# %%
scalar = StandardScaler()
y = boston_data.target        
X = boston_df.values             #tomaremos todos los columnas para entrenar
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print("TRAIN--> X: {} - Y: {}".format(X_train.shape,y_train.shape))
print("TEST--> X: {} - Y: {}".format(X_test.shape,y_test.shape))
# Out:
# TRAIN--> X: (404, 13) - Y: (404,)
# TEST--> X: (102, 13) - Y: (102,)

# %% [markdown]
# ###Aplicar regressión lineal

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
#entrenamos
regressor.fit(X_train, y_train)
#predecimos
pred = regressor.predict(X_test)

# %% [markdown]
# visualizar la regresión

# %%
#visualizar la predicción en los datos de testeo
plt.scatter(y_test, pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], c='r', lw=2)
plt.show()
print("Precisión del modelo: "+str(regressor.score(X_test, y_test)))
# Out:
# Precisión del modelo: 0.792708114809324

# %% [markdown]
# #Valores obtenidos

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/2HenryCardenas1/DeepLearning/main/DataFrames/dataFrameLoadBoston.csv")
df.head(33)

# %%
value = df[df['Precision del modelo'] >= '0.8']
value.head()
# Out:
#        Valores Porcentaje evaluado Precision del modelo  Random state
# 4   CRIM-LSTAT               70-30   0.6659159843031395          30.0
# 9     DIST-NOX               70-30   0.8137154330034226          20.0
# 20    ZN-INDUS               70-30   0.8066121871374812          20.0
